# %% [markdown]
# <h1>Gaussian Random Data</h1>

# %%
import numpy as np
x = np.random.randn(10000)

# %% [markdown]
# <h1>Using the Artist layer</h1>

# %%
# %matplotlib inline
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvas(fig)

ax = fig.add_subplot(111)
ax.hist(x, 100)

ax.set_title(r'Normal distribution with $\mu=0, \sigma=1$')
fig.savefig('matplotlib histogram.png')

# %% [markdown]
# <img src='matplotlib histogram.png' />

# %% [markdown]
# <h1>Using the Scripting layer</h1>

# %% [markdown]
# <h2>matplotlib in inline mode</h2>

# %%
import matplotlib.pyplot as plt
plt.hist(x, 100)
plt.plot(0, 300, 'o')
plt.title(r'Normal distribution with $\mu=0, \sigma=1$')
plt.savefig('matplotlib histogram.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_112380\2128348373.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 mode = x.mode()
#       3 plt.hist(x, 100)
#       4 plt.plot(mod, 200, 'o')
#       5 plt.plot(0, 300, 'o')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'mode'

# %% [markdown]
# <h2>matplotlib in notebook mode</h2>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.hist(x, 100)
plt.show()

plt.plot(0, 300, 'o')
plt.title(r'Normal distribution with $\mu=0, \sigma=1$')
plt.savefig('matplotlib histogram.png')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h1>Canadian Immigration Data</h1>

# %%
# !pip install xlrd
# !pip install openpyxl
# !pip install js
import pandas as pd
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 115.0/115.0 kB 6.5 MB/s eta 0:00:00
# ...
#   Created wheel for js: filename=js-1.0-py3-none-any.whl size=2884 sha256=0a1ebb97d6625025471847caf727549b8ac261da285c742260b0c9c93a8198de
#   Stored in directory: c:\users\mark\appdata\local\pip\cache\wheels\6f\91\12\9fc79cc62b07127faf39b5f3afcc6606e659bb54743a00bebb
# ...
#   Created wheel for shutilwhich: filename=shutilwhich-1.1.0-py3-none-any.whl size=2767 sha256=27e07ac4c81c344e2d608db7c9fc6d442eefcc9bb525a9d0cb7dbad6748e2b2d
#   Stored in directory: c:\users\mark\appdata\local\pip\cache\wheels\84\c7\f5\fed66dce1ed897b44e0da776b6a592dfad0a70f7dd61f73a9d
# Successfully built js shutilwhich
# ...

# %%
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx'
resp = await fetch(URL)
text = io.BytesIO((await resp.arrayBuffer()).to_py())

df_can = pd.read_excel(
    text,
    sheet_name='Canada by Citizenship',
    skiprows=range(20),
    skipfooter=2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_112380\1962386013.py in <module>
# ----> 1 from js import fetch
#       2 import io
#       3
#       4 URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx'
#       5 resp = await fetch(URL)
#
# ImportError: cannot import name 'fetch' from 'js' (C:\Users\Mark\anaconda3\lib\site-packages\js\__init__.py)
